# %%
import os
import glob
from tqdm import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile
from python_speech_features import mfcc , logfbank
import librosa as lr
import pickle
import librosa
from scipy import signal
get_ipython().magic('matplotlib inline')
#%matplotlib nbagg
import soundfile
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# %%
#Loading the required RAVDESS DataSet with length of 1439 Audio Files 
def getListOfFiles(dirName):
    listOfFile=os.listdir(dirName)
    allFiles=list()
    for entry in listOfFile:
        fullPath=os.path.join(dirName, entry)
        if os.path.isdir(fullPath):
            allFiles=allFiles + getListOfFiles(fullPath)
        else:
            allFiles.append(fullPath)
    return allFiles

dirName = './speech-emotion-recognition-ravdess-data'
listOfFiles = getListOfFiles(dirName)
len(listOfFiles)
# Out:
# 1439

# %%
#Use the Speech-Recognition API to get the Raw Text from Audio Files, Though Speech Recognition
#is less strong for large chunk of files , so used Error Handling , where when it is not be able to 
#produce the text of a particular Audio File it prints the statement 'error'.Just for understanding Audio
import speech_recognition as sr
r=sr.Recognizer()
for file in range(0 , len(listOfFiles) , 1):
    with sr.AudioFile(listOfFiles[file]) as source:
        audio = r.listen(source)
        try:
            text = r.recognize_google(audio)
            print(text)
        except:
            print('error')
# Out:
# is it talking by the door
# dog sitting by the door
# talk to Siri why the door
# error
# error
# error
# dog sitting by the door
# change your talking by the door
# kids talking by the door
# dogs sitting by the door
# sitting by the
# kids talking by the door
# talking by the door
# dog sitting by the door
# error
# talking by the door
# error
# sitting by the door
# error
# kids talking by the door
# khesa talking by the door
# error
# error
# kids talking by the door
# talking by the door
# dogs sitting by the door
# sitting by the door
# talking by the door
# is a talking by the door
# the door
# error
# the door
# Earth talking by the door
# frogs are sitting by the door
# dogs are sitting at the door
# talking by the door
# kids talking by the door
# dogs sitting by the door
# dogs sitting by the door
# f****** by the door
# is the talking to the door
# Rockstar ceiling by the door
# ceiling by the
# error
# khinch
# sitting by the door
# coronavirus
# kids talking by the door
# talking by the door
# tour tour
# exit the door
# kids talking
# kids talking by the door
# dogs sitting by the door
# error
# Ijjat
# talking by the door
# sitting by the door
# toxicity by the door
# kids talking by the door
# kids talking by the door
# dogs are sitting by the door
# talk just sitting by the door
# it's a talking by the door
# hits at hacking by the door
# dogs are sitting by the tower
# sitting by the door
# kids talking by the
# kids attacking Bible
# dogs are sitting by the door
# tags setting
# talking by the door
# error
# dogs are sitting by the door
# dogs are sitting by the door
# error
# error
# jobs in sitting by the driver
# Jhansi
# Ijjat Hawking by the tour
# talking by the door
# dogs sitting by the door
# target setting by the tour
# talking by the tour
# Ijjat hacking by the to
# talk with sitting by the tour
# talk was sitting by the tour
# talking by the door
# talking by the door
# dog sitting by the door
# dog sitting by the door
# talking by the door
# kids talking about the door
# dogs are standing by the door
# dogs sitting by the door
# talking by the door
# talking by the Joker
# tox was sitting by the Joker
# talk just sitting by the Shore
# error
# Talking Ben the dog
# talks of cinema
# top 15 budget
# talking by the door
# f****** by the door
# error
# top just sitting by the door
# kids f****** by the door
# kids talking by the door
# dogs staring by the door
# dogs staring by the door
# talking by the door
# talking by the door
# sitting by the door
# talk to setting by the door
# the door
# talking
# error
# error
# talking by the door
# talking
# sitting by the door
# charger sitting by the door
# talking Titan
# talking by the door
# error
# Siri
# talking by the door
# talking bicycle
# error
# charge sharing by the tour
# error
# by the door
# sitting by the Shore
# sitting by the door
# whore
# talking
# talk to the door
# sitting by the door
# Satta King
# hit the talking by the door
# set setting
# search string by date
# Pitbull
# error
# error
# ek baat Bataun
# talking part 2
# talking
# accident
# error
# balto
# talking toe
# error
# error
# talking
# are talking by the door
# torturing fight over
# Ram Charan father
# error
# which is the tour
# error
# shortest path
# Jharkhand
# talking
# sharing button
# thought that setting barbacoa
# hot
# Chetan
# dogs are sitting pattern
# sitting by the door
# error
# error
# error
# ceiling fan
# error
# error
# error
# staring at the door
# talking by the door
# talking by the door
# dog racing by the door
# top 10 sitting by the door
# talking by the driver
# talking by the dohe
# dogs sitting by the door
# dogs at sitting batua
# kids at hacking but it over
# talking by the tower
# Agra sitting by the tower
# dogs sitting at the door
# the talking by the river
# talking by the door
# Etawah
# chocolate selling by the Joker
# the talking by the door
# talking baddua
# stop the string that over
# error
# talking by the tower
# the talking by the door
# stop the sitting by the door
# top 10 sitting by the door
# error
# weather tour
# error
# error
# talking by the door
# error
# sitting by the door
# dog sitting by the door
# error
# error
# show the sitting by the drawer
# error
# talking by the door
# talking by the door
# stock was sitting by the door
# sitting by the door
# error
# error
# error
# error
# shit talking by the door
# talking but the door
# dog sitting by the door
# setting button
# talking by the door
# talking by the door
# top 10 sitting by the door
# stock that ceiling budget tour
# Utha Ke Mare Jor
# talking by the door
# sitting by the door
# sitting by the door
# at the door
# ki badi Jor
# error
# or
# kids are talking by the door
# kids are talking by the door
# dogs setting bar the door
# dogs are sitting by the door
# kids are talking by the door
# kids are talking
# dogs are sitting party door
# dogs are sitting by the door
# Kates 8 parking
# shades
# error
# dogs are sitting
# kids talking by the door
# talking by the door
# error
# dogs sitting by the door
# Kids Art
# Khet aur talking by the door
# error
# the door
# kids talking by the door
# kids are talking by the door
# talk it over
# dogs are sitting by the door
# error
# Khesari talking at the door
# roxid syrup
# transistor in motherboard
# are talking by the
# kids are talking by the door
# dogs are sitting by the door
# error
# kids talking by the door
# tricks of talking for the tour
# ostrich
# auto
# error
# kids talking
# error
# error
# kids talk in Coimbatore
# Kids Art
# talk it over
# Georgette saree madarchod
# Kids Art talking
# Khet Jaat Hawking
# error
# error
# kids are talking
# kids are talking
# sharing
# no
# error
# kids out of the door
# error
# error
# kids are talking
# error
# error
# Shri
# kids talking by the door
# kids are talking by the door
# talk the sitting by the door
# ok just sitting by the door
# talking
# talking by the door
# Jagdish tearing by the door
# jagra staring by the
# error
# error
# Jug staring by the door
# chagas ring by with
# talking by the door
# error
# dog racing Bai wadyavar
# sitting by the door
# error
# error
# error
# error
# kids talking by the door
# talking by the door
# dogs are sitting by the door
# dogs selling by the door
# error
# error
# error
# stock
# talking by the door
# talking by the door
# dog sitting by the door
# dog sitting by the door
# error
# error
# error
# error
# error
# kids talking by the door
# error
# error
# error
# error
# error
# error
# error
# error
# dogs sitting by the door
# chirang private job
# error
# talking bhai
# error
# Tik Tok best ringtone
# the talking by the door
# Kidhar talking by the door
# error
# error
# talking
# error
# error
# error
# Heather talking by weather
# theatre talking by the door
# sitting by the door
# dog sitting by the door
# Khetri talking by the tower
# Khet the talking by the tower
# dog sitting by the door
# dog staring by the door
# Khesari talking by the door
# talking by the door
# Tiranga
# sharing
# talking by the door
# talking by the door
# daw
# daw
# error
# is talking by the door
# sitting by the door
# sitting by the door
# talking by the door
# the talking by the door
# dogs are sitting by the door
# dogs are sitting by the door
# a talking by the tour
# error
# error
# toxicity
# kids are talking by the door
# kids are talking by the door
# sitting by the door
# dogs are sitting by the door
# error
# kids are talking by the door
# Rodger sitting by the door
# frogs are sitting by the door
# talking
# talking by the door
# dogs are sitting by the door
# sitting by the door
# error
# error
# chor
# talks at the door
# the talking by the door
# talking by the door
# error
# sitting by the door
# talking by the door
# error
# error
# are sitting
# kids talking by the door
# talking by the
# sitting by the door
# sitting by the door
# hot hot by the door
# talking by the door
# error
# sitting by the door
# Kshetra talk in Bangalore
# Khet the talking father
# toxicity in Baroda
# top 10 selling badhava
# cat talking Badshah
# kya thak in Bangalore
# target store in Bangalore
# dogs for sale in Bangalore
# kheti talking bad boy
# Khesari talking bar door
# chocolates in Bangalore
# toxicity
# Hitler talking by the door
# talking by the door
# tantrik shrimp
# subject current by the door
# talking by the door
# talking
# talking by the door
# sharing Goa
# coronavirus
# talking by the door
# talking by the door
# dog sitting by the door
# error
# error
# error
# earring by the top
# error
# cute talking by the door
# talking by the door
# talk with sitting by the door
# sitting by the door
# you talking by the door
# kids talking by the door
# sitting by the door
# setting
# talking baisa Dhol
# talking bhai with
# ka exit setting bi de do
# Congress ringtone
# kids talking by the door
# kids talking by the door
# the door
# dog sitting by the door
# talking by the door
# kids talking
# error
# error
# kids talking by the door
# Khesari talking by the door
# sent by the door
# Rajashree byndoor
# error
# error
# error
# error
# themes
# error
# error
# sitting by the door
# or
# error
# aur
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# kids talking by the door
# kids
# error
# weather
# kids are talking by the door
# kids are talking by the door
# dogs
# error
# talking by the door
# kids talking by the door
# sitting by the door
# talks at sitting by the door
# talking by the door
# talking by the door
# stop staring by the door
# sister in by the door
# talking by the door
# error
# start saying by the tour
# accessory weather
# talking by the door
# talking by the door
# jobs in sitting by the door
# the door
# error
# error
# error
# error
# talking by the door
# talking by the tower
# Sonakshi Sinha the tour
# bhagyashri weather tour
# talking by the tour
# error
# thoughts
# error
# talking by the door
# the talking by the door
# jobs Sterling by the door
# error
# talking by the door
# open door
# daw
# show the setting
# talking by the tour
# Khet
# Shriman Ji dwara
# accessing by the to earth
# Johar
# error
# error
# error
# talking by the door
# talking by the door
# dogs sitting by the door
# the door
# error
# Hawking weather
# error
# or
# error
# error
# error
# error
# error
# talking at the door
# error
# error
# talking by the door
# talking by the door
# dog sitting by the door
# translate sitting by the door
# Khesari talking by the door

# %%
#Plotting the Basic Graphs for understanding of Audio Files :
for file in range(0 , len(listOfFiles) , 200):
    audio , sfreq = lr.load(listOfFiles[file])
    time = np.arange(0 , len(audio)) / sfreq
    
    fig ,ax = plt.subplots()
    ax.plot(time , audio)
    ax.set(xlabel = 'Time (s)' , ylabel = 'Sound Amplitude')
    plt.show()
    
#PLOT THE SEPCTOGRAM
for file in range(0 , len(listOfFiles) , 200):
     sample_rate , samples = wavfile.read(listOfFiles[file])
     frequencies , times, spectrogram = signal.spectrogram(samples, sample_rate) 
     plt.pcolormesh(times, frequencies, spectrogram, shading='auto')
     plt.imshow(spectrogram)
     plt.ylabel('Frequency [Hz]')
     plt.xlabel('Time [sec]')
     plt.show()

# %%
#Next Step is In-Depth Visualisation of Audio Files and its certain features to plot for.
#They are the Plotting Functions to be called later. 
def plot_signals(signals):
    fig , axes = plt.subplots(nrows=2, ncols=5,sharex =False , sharey=True, figsize=(20,5))
    fig.suptitle('Time Series' , size=16)
    i=0
    for x in range(2):
        for y in range(5):
            axes[x,y].set_title(list(signals.keys())[i])
            axes[x,y].plot(list(signals.values())[i])
            axes[x,y].get_xaxis().set_visible(False)
            axes[x,y].get_yaxis().set_visible(False)
            i +=1

def plot_fft(fft):
    fig , axes = plt.subplots(nrows=2, ncols=5,sharex =False , sharey=True, figsize=(20,5))
    fig.suptitle('Fourier Transform' , size=16)
    i=0
    for x in range(2):
        for y in range(5):
            data = list(fft.values())[i]
            Y,freq = data[0] , data[1]
            axes[x,y].set_title(list(fft.keys())[i])
            axes[x,y].plot(freq , Y)
            axes[x,y].get_xaxis().set_visible(False)
            axes[x,y].get_yaxis().set_visible(False)
            i +=1
    
def plot_fbank(fbank):
    fig , axes = plt.subplots(nrows=2, ncols=5,sharex =False , sharey=True, figsize=(20,5))
    fig.suptitle('Filter Bank Coefficients' , size=16)
    i=0
    for x in range(2):
        for y in range(5):
            axes[x,y].set_title(list(fbank.keys())[i])
            axes[x,y].imshow(list(fbank.values())[i],cmap='hot', interpolation = 'nearest')
            axes[x,y].get_xaxis().set_visible(False)
            axes[x,y].get_yaxis().set_visible(False)
            i +=1
            
def plot_mfccs(mfccs):
    fig , axes = plt.subplots(nrows=2, ncols=5,sharex =False , sharey=True, figsize=(20,5))
    fig.suptitle('Mel Frequency Capstrum Coefficients' , size=16)
    i=0
    for x in range(2):
        for y in range(5):
            axes[x,y].set_title(list(mfccs.keys())[i])
            axes[x,y].imshow(list(mfccs.values())[i],
                             cmap='hot', interpolation = 'nearest')
            axes[x,y].get_xaxis().set_visible(False)
            axes[x,y].get_yaxis().set_visible(False)
            i +=1

def calc_fft(y,rate):
    n = len(y)
    freq = np.fft.rfftfreq(n , d= 1/rate)
    Y= abs(np.fft.rfft(y)/n)
    return(Y,freq)

# %%
# Here The Data Set is loaded and plots are Visualised by Calling the Plotting Functions . 
import matplotlib.pyplot as plt
from scipy.io import wavfile as wav
from scipy.fftpack import fft
import numpy as np
for file in range(0 , len(listOfFiles)-1 , 200):
    rate, data = wav.read(listOfFiles[file])
    fft_out = fft(data)
    # %matplotlib inline
    plt.plot(data, np.abs(fft_out))
    plt.show()
    
signals={}
fft={}
fbank={}
mfccs={}
# load data
for file in range(0 , len(listOfFiles)-1 , 200):
     rate, data = wavfile.read(listOfFiles[file])
     signal,rate =librosa.load(listOfFiles[file] , sr=44100)
     mask = envelope(signal , rate , 0.0005)
     signals[file] = signal
     fft[file] = calc_fft(signal , rate)
    
     bank = logfbank(signal[:rate] , rate , nfilt = 26, nfft = 1103).T
     fbank[file] = bank
     mel = mfcc(signal[:rate] , rate , numcep =13 , nfilt = 26 , nfft=1103).T
     mfccs[file]=mel

plot_signals(signals)
plt.show()

plot_fft(fft)
plt.show()

plot_fbank(fbank)
plt.show()

plot_mfccs(mfccs)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-10f4b1221a0b> in <module>
#      28      mfccs[file]=mel
#      29
# ---> 30 plot_signals(signals)
#      31 plt.show()
#      32
#
# <ipython-input-6-3f707c5293af> in plot_signals(signals)
#       7     for x in range(2):
#       8         for y in range(5):
# ----> 9             axes[x,y].set_title(list(signals.keys())[i])
#      10             axes[x,y].plot(list(signals.values())[i])
#      11             axes[x,y].get_xaxis().set_visible(False)
#
# IndexError: list index out of range

# %%
#Now Cleaning Step is Performed where:
#DOWN SAMPLING OF AUDIO FILES IS DONE  AND PUT MASK OVER IT AND DIRECT INTO CLEAN FOLDER
#MASK IS TO REMOVE UNNECESSARY EMPTY VOICES AROUND THE MAIN AUDIO VOICE 
def envelope(y , rate, threshold):
    mask=[]
    y=pd.Series(y).apply(np.abs)
    y_mean = y.rolling(window=int(rate/10) ,  min_periods=1 , center = True).mean()
    for mean in y_mean:
        if mean>threshold:
            mask.append(True)
        else:
            mask.append(False)
    return mask

# %%
#The clean Audio Files are redirected to Clean Audio Folder Directory 
import glob,pickle
for file in tqdm(glob.glob(r'D:\Documents\ml\Speech_Emotion_Detection\Speech_Emotion_Detection\speech-emotion-recognition-ravdess-data\\**\\*.wav')):
    file_name = os.path.basename(file)
    signal , rate = librosa.load(file, sr=16000)
    mask = envelope(signal,rate, 0.0005)
    wavfile.write(filename= r'D:\Documents\ml\Speech_Emotion_Detection\Speech_Emotion_Detection\cleaned_audio\\'+str(file_name), rate=rate,data=signal[mask])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1439/1439 [00:32<00:00, 44.93it/s]

# %%
#Feature Extraction of Audio Files Function 
#Extract features (mfcc, chroma, mel) from a sound file
def extract_feature(file_name, mfcc, chroma, mel):
    with soundfile.SoundFile(file_name) as sound_file:
        X = sound_file.read(dtype="float32")
        sample_rate=sound_file.samplerate
        if chroma:
            stft=np.abs(librosa.stft(X))
        result=np.array([])
        if mfcc:
            mfccs=np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T, axis=0)
        result=np.hstack((result, mfccs))
        if chroma:
            chroma=np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
        result=np.hstack((result, chroma))
        if mel:
            mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
        result=np.hstack((result, mel))
    return result

# %%
#Emotions in the RAVDESS dataset to be classified Audio Files based on . 
emotions={
  '01':'neutral',
  '02':'calm',
  '03':'happy',
  '04':'sad',
  '05':'angry',
  '06':'fearful',
  '07':'disgust',
  '08':'surprised'
}
#These are the emotions User wants to observe more :
observed_emotions=['neutral', 'calm', 'happy', 'angry']

# %%
#Load the data and extract features for each sound file
from glob import glob
import os
import glob
def load_data(test_size):
    x,y=[],[]
    for file in glob.glob("D:\Documents\ml\Speech_Emotion_Detection\Speech_Emotion_Detection\cleaned_audio\\*.wav"):
        file_name=os.path.basename(file)
        emotion=emotions[file_name.split("-")[2]]
        if emotion not in observed_emotions:
            continue
        feature=extract_feature(file, mfcc=True, chroma=True, mel=True)
        x.append(feature)
        y.append(emotion)
    return train_test_split(np.array(x), y, test_size=test_size, random_state=9)

# %%
#Splitting the dataset
x_train,x_test,y_train,y_test=load_data(test_size=0.25)
print((x_train.shape[0], x_test.shape[0]))
print(f'Features extracted: {x_train.shape[1]}')
# Out:
# (503, 168)
# Features extracted: 180

# %%
# Initialize the Multi Layer Perceptron Classifier
model=MLPClassifier(alpha=0.01, batch_size=256, hidden_layer_sizes=300, learning_rate='adaptive', max_iter = 1000)

# %%
#Train the model
model.fit(x_train,y_train)
# Out:
# MLPClassifier(activation='relu', alpha=0.01, batch_size=256, beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=300, learning_rate='adaptive',
#               learning_rate_init=0.001, max_fun=15000, max_iter=1000,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)

# %%
#SAVING THE MODEL
import pickle
# Save the Modle to file in the current working directory
#For any new testing data other than the data in dataset

Pkl_Filename = "Voice_Emotion_Detection_Model.pkl"  

with open(Pkl_Filename, 'wb') as file:  
    pickle.dump(model, file)

# %%
# Load the Model back from file
Pkl_Filename = "Voice_Emotion_Detection_Model.pkl" 
with open(Pkl_Filename, 'rb') as file:  
    Voice_Emotion_Detection_Model = pickle.load(file)

Voice_Emotion_Detection_Model
# Out:
# MLPClassifier(activation='relu', alpha=0.01, batch_size=256, beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=300, learning_rate='adaptive',
#               learning_rate_init=0.001, max_fun=15000, max_iter=1000,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)

# %%
#predicting :
y_pred=Voice_Emotion_Detection_Model.predict(x_test)
y_pred
# Out:
# array(['neutral', 'neutral', 'happy', 'happy', 'neutral', 'neutral',
#        'calm', 'happy', 'neutral', 'calm', 'calm', 'happy', 'angry',
#        'neutral', 'calm', 'calm', 'happy', 'neutral', 'angry', 'happy',
#        'happy', 'neutral', 'angry', 'neutral', 'happy', 'angry', 'happy',
#        'angry', 'happy', 'angry', 'happy', 'angry', 'angry', 'angry',
#        'angry', 'angry', 'calm', 'angry', 'neutral', 'neutral', 'angry',
#        'calm', 'calm', 'angry', 'calm', 'happy', 'neutral', 'calm',
#        'calm', 'calm', 'happy', 'happy', 'happy', 'angry', 'calm',
#        'angry', 'angry', 'neutral', 'calm', 'angry', 'angry', 'angry',
#        'angry', 'calm', 'happy', 'angry', 'calm', 'calm', 'happy', 'calm',
#        'happy', 'happy', 'angry', 'angry', 'angry', 'happy', 'neutral',
#        'calm', 'calm', 'calm', 'happy', 'happy', 'angry', 'angry',
#        'angry', 'happy', 'angry', 'happy', 'neutral', 'calm', 'happy',
#        'angry', 'calm', 'happy', 'calm', 'angry', 'neutral', 'happy',
#        'calm', 'happy', 'angry', 'happy', 'calm', 'angry', 'neutral',
#        'calm', 'neutral', 'angry', 'calm', 'angry', 'neutral', 'calm',
#        'happy', 'neutral', 'neutral', 'happy', 'angry', 'angry', 'happy',
#        'neutral', 'neutral', 'angry', 'happy', 'calm', 'neutral', 'calm',
#        'calm', 'happy', 'calm', 'calm', 'neutral', 'angry', 'angry',
#        'happy', 'neutral', 'happy', 'angry', 'happy', 'angry', 'neutral',
#        'calm', 'calm', 'angry', 'calm', 'angry', 'angry', 'calm', 'happy',
#        'neutral', 'angry', 'happy', 'angry', 'calm', 'angry', 'happy',
#        'angry', 'happy', 'angry', 'angry', 'happy', 'calm', 'happy',
#        'happy', 'happy', 'angry', 'neutral', 'neutral', 'calm'],
#       dtype='<U7')

# %%
accuracy=accuracy_score(y_true=y_test, y_pred=y_pred)
print("Accuracy: {:.2f}%".format(accuracy*100))
# Out:
# Accuracy: 85.12%

# %%
#Store the Prediction probabilities into CSV file 
import numpy as np
import pandas as pd
y_pred1 = pd.DataFrame(y_pred, columns=['predictions'])
#y_pred1['file_names'] = test_filename
print(y_pred1)
y_pred1.to_csv('predictionfinal.csv')
# Out:
#     predictions
# 0       neutral
# 1       neutral
# 2         happy
# 3         happy
# 4       neutral
# ..          ...
# 163       happy
# 164       angry
# 165     neutral
# 166     neutral
# 167        calm
#
# [168 rows x 1 columns]

# %%
# import required libraries
import sounddevice as sd
from scipy.io.wavfile import write
import wavio as wv

# Sampling frequency
freq = 44100

# Recording duration
duration = 4

# Start recorder with the given values
# of duration and sample frequency
recording = sd.rec(int(duration * freq),
				samplerate=freq, channels=2)

# Record audio for the given number of seconds
print("* recording")
sd.wait()
print("* done recording")

# This will convert the NumPy array to an audio
# file with the given sampling frequency
write("output0.wav", freq, recording)

# Convert the NumPy array to audio file
wv.write("output1.wav", recording, freq, sampwidth=2)
# Out:
# * recording
# * done recording

# %%
#The file 'output1.wav' in the previous cell is the file that was recorded live using the code :
data, sampling_rate = librosa.load('output1.wav')
# %matplotlib inline
import os
import pandas as pd
import librosa.display
import glob 

plt.figure(figsize=(15, 5))
librosa.display.waveplot(data, sr=sampling_rate)

# %%
## Appying extract_feature function on random file and then loading model to predict the result 
file1 = os.path.basename('output1.wav')
file_name = os.path.basename(file1)
signal , rate = librosa.load(file1, sr=16000)
mask = envelope(signal,rate, 0.0005)
wavfile.write(filename= r'D:\Documents\ml\Speech_Emotion_Detection\Speech_Emotion_Detection\\'+str(file_name), rate=rate,data=signal[mask])

new_feature = extract_feature(file1, mfcc=True, chroma=True, mel=True)

# data.shape

predicted = Voice_Emotion_Detection_Model.predict([new_feature])
print(predicted[0])
# Out:
# angry
